# %% [markdown]
# ### Import

# %%
import os
import pandas as pd
import re
import numpy as np
from transformers import AutoTokenizer, AutoModel
import torch
import spacy
from collections import defaultdict
from sklearn.model_selection import train_test_split
import ast
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.utils import to_categorical
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Preprocessing

# %%
def preprocess_articles(article_dir):
    """
    Preprocess the article files by extracting filenames and text content into a DataFrame.

    Args:
    - article_dir (str): Directory path containing article `.txt` files.

    Returns:
    - pandas.DataFrame: DataFrame with columns ['article_id', 'text'].
    """
    # List to store article data
    articles = []

    # Loop through each file in the directory
    for filename in os.listdir(article_dir):
        if filename.endswith(".txt"):
            file_path = os.path.join(article_dir, filename)

            # Read the file content
            with open(file_path, 'r', encoding='utf-8') as file:
                lines = file.readlines()

                # Extract the text: skip title (first row) and empty line (second row)
                title = lines[0].strip() if len(lines) > 0 else ""
                content = " ".join(line.strip() for line in lines[2:])

                # Append the extracted data
                articles.append({'article_id': filename, 'text': title + "\n" + content})

    # Create a DataFrame
    article_df = pd.DataFrame(articles)

    return article_df

# Preprocessing the annotations and merging with the article.
def preprocess_annotations(annotation_file, article_df):
    """
    Preprocess the annotation file and merge annotations with the article DataFrame.

    Args:
    - annotation_file (str): Path to the annotation file (tab-separated).
    - article_df (pandas.DataFrame): DataFrame with article IDs and texts.

    Returns:
    - pandas.DataFrame: Merged DataFrame with columns ['article_id', 'text', 'narratives', 'subnarratives'].
    """
    # Read the annotation file
    annotations = pd.read_csv(annotation_file, sep='\t', header=None,
                               names=['article_id', 'narratives', 'subnarratives'])

    # Merge the annotation data with the article DataFrame
    merged_df = pd.merge(article_df, annotations, on='article_id', how='left')

    # Fill missing values for narratives and subnarratives with 'Other'
    merged_df['narratives'] = merged_df['narratives'].fillna('Other')
    merged_df['subnarratives'] = merged_df['subnarratives'].fillna('Other')

    return merged_df

# Taxonomies Processing
def parse_taxonomy(taxonomy_str):
    """
    Parse a taxonomy string into a hierarchical dictionary.

    Args:
    - taxonomy_str (str): Taxonomy string, e.g., 'x:y; x:z; x:y:a'

    Returns:
    - dict: Hierarchical representation of the taxonomy.
    """
    taxonomy_dict = {}
    if taxonomy_str == "Other" or not taxonomy_str:
        return {"Other": {"level_1": [], "level_2": {}}}

    entries = taxonomy_str.split(";")
    for entry in entries:
        levels = entry.split(":")
        x = levels[0]  # Top-level narrative
        y = levels[1] if len(levels) > 1 else "Other"
        a = levels[2] if len(levels) > 2 else None

        if x not in taxonomy_dict:
            taxonomy_dict[x] = {"level_1": [], "level_2": {}}

        if y != "Other" and y not in taxonomy_dict[x]["level_1"]:
            taxonomy_dict[x]["level_1"].append(y)

        if a and y != "Other":
            if y not in taxonomy_dict[x]["level_2"]:
                taxonomy_dict[x]["level_2"][y] = []
            if a not in taxonomy_dict[x]["level_2"][y]:
                taxonomy_dict[x]["level_2"][y].append(a)

    return taxonomy_dict


def expand_taxonomies(df, narrative_col, subnarrative_col):
    """
    Expand taxonomies into hierarchical format.

    Args:
    - df (pd.DataFrame): DataFrame with taxonomy columns.
    - narrative_col (str): Column name for narrative-level taxonomies.
    - subnarrative_col (str): Column name for sub-narrative-level taxonomies.

    Returns:
    - pd.DataFrame: Expanded DataFrame with hierarchical taxonomy extraction.
    """
    expanded_data = []

    for _, row in df.iterrows():
        article_id = row['article_id']
        narratives = parse_taxonomy(row[narrative_col])
        subnarratives = parse_taxonomy(row[subnarrative_col])

        for narrative, details in narratives.items():
            for level_1 in details['level_1']:
                if level_1 in subnarratives[narrative]["level_2"]:
                    for level_2 in subnarratives[narrative]["level_2"][level_1]:
                        expanded_data.append({
                            "article_id": article_id,
                            "narrative": narrative,
                            "level_1": level_1,
                            "level_2": level_2
                        })
                else:
                    expanded_data.append({
                        "article_id": article_id,
                        "narrative": narrative,
                        "level_1": level_1,
                        "level_2": "Other"
                    })
            if not details['level_1']:  # If no level 1 for a narrative
                expanded_data.append({
                    "article_id": article_id,
                    "narrative": narrative,
                    "level_1": "Other",
                    "level_2": "Other"
                })

    return pd.DataFrame(expanded_data)


def load_annotations(file_path):
    """
    Load and process annotations from a file into a DataFrame.

    Args:
    - file_path (str): Path to the annotations file.

    Returns:
    - pandas.DataFrame: DataFrame with columns ['article_id', 'narratives', 'subnarratives'].
    """
    # Load the file into a DataFrame
    annotations = pd.read_csv(file_path, sep='\t', header=None,
                               names=['article_id', 'narratives', 'subnarratives'])

    # Fill missing values with 'Other'
    annotations['narratives'] = annotations['narratives'].fillna('Other')
    annotations['subnarratives'] = annotations['subnarratives'].fillna('Other')

    return annotations


# Training data = train_articles, Development data = dev_articles
train_articles_path = '/content/drive/MyDrive/NLP_Proj/target_4_December_release/RU/raw-documents'
train_articles = preprocess_articles(train_articles_path)
dev_articles_path = '/content/drive/MyDrive/NLP_Proj/cleaned_dev_10_january_2025/RU/subtask-2-documents'
dev_articles = preprocess_articles(dev_articles_path)
#print(article_df.head())


# Annotations for training and dev
annotations_train_path = '/content/drive/MyDrive/NLP_Proj/target_4_December_release/RU/subtask-2-annotations.txt'
annotations_train_df = load_annotations(annotations_train_path)
expanded_train_annotations = expand_taxonomies(annotations_train_df, 'narratives', 'subnarratives')

annotations_dev_path = '/content/drive/MyDrive/NLP_Proj/cleaned_dev_10_january_2025/RU/subtask-2-annotations.txt'
annotations_dev_df = load_annotations(annotations_dev_path)
expanded_dev_annotations = expand_taxonomies(annotations_dev_df, 'narratives', 'subnarratives')

# %%
np.unique(expanded_train_annotations['narrative'])
# Out:
# array(['URW'], dtype=object)

# %%
train_articles.head()
# Out:
#         article_id                                               text
# 0  RU-URW-1017.txt  Дмитрий Стешин: Россия тихо глушит GPS европей...
# 1  RU-URW-1021.txt  23:55 Лукашенко обвинил Запад в стремлении к е...
# 2  RU-URW-1031.txt  Лихачев: РФ ждет от ООН оценку действий Киева ...
# 3  RU-URW-1025.txt  Финский наемник Сирен раскритиковал подготовку...
# 4  RU-URW-1011.txt  Если ВС РФ расширят фронт, США позволят Украин...

# %% [markdown]
# ### Statistics on data

# %%
print("Len of train articles:", len(train_articles))
print("Len of dev articles:", len(dev_articles))

print("Len of dev annotation:", len(expanded_train_annotations))
print("Len of dev annotation:", len(expanded_dev_annotations))
# Out:
# Len of train articles: 133
# Len of dev articles: 32
# Len of dev annotation: 272
# Len of dev annotation: 79

# %%
narrative_unique = sorted(set(expanded_train_annotations['narrative']))
narrative_dev_unique = sorted(set(expanded_dev_annotations['narrative']))

print(len(narrative_unique), narrative_unique)
print(len(narrative_dev_unique), narrative_dev_unique)
# Out:
# 1 ['URW']
# 2 ['Other', 'URW']

# %%
Level_1_unique = sorted(set(expanded_train_annotations['level_1']))
Level_2_unique = sorted(set(expanded_train_annotations['level_2']))

print(len(Level_1_unique), Level_1_unique)
print(len(Level_2_unique), Level_2_unique)
# Out:
# 11 [' Amplifying war-related fears', ' Blaming the war on others rather than the invader', ' Discrediting Ukraine', ' Discrediting the West, Diplomacy', ' Distrust towards Media', ' Hidden plots by secret schemes of powerful groups', ' Negative Consequences for the West', ' Overpraising the West', ' Praise of Russia', ' Russia is the Victim', ' Speculating war outcomes']
# 30 [' By continuing the war we risk WWIII', ' Diplomacy does/will not work', ' Discrediting Ukrainian government and officials and policies', ' Discrediting Ukrainian military', ' Discrediting Ukrainian nation and society', ' NATO should/will directly intervene', ' Other', ' Praise of Russian President Vladimir Putin', ' Praise of Russian military might', ' Rewriting Ukraine’s history', ' Russia actions in Ukraine are only self-defence', ' Russia has international support from a number of countries and people', ' Russia is a guarantor of peace and prosperity', ' Russia will also attack other countries', ' Situation in Ukraine is hopeless', ' The EU is divided', ' The West are the aggressors', ' The West does not care about Ukraine, only about its interests', ' The West is overreacting', ' The West is russophobic', ' The West is weak', ' The conflict will increase the Ukrainian refugee flows to Europe', ' There is a real possibility that nuclear weapons will be employed', ' UA is anti-RU extremists', ' Ukraine is a puppet of the West', ' Ukraine is associated with nazism', ' Ukraine is the aggressor', ' Ukrainian army is collapsing', ' Ukrainian media cannot be trusted', ' Western media is an instrument of propaganda']

# %%
Level_1_unique = sorted(set(expanded_train_annotations['level_1']))
Level_2_unique = sorted(set(expanded_train_annotations['level_2']))

print(len(Level_1_unique), Level_1_unique)
print(len(Level_2_unique), Level_2_unique)
# Out:
# 11 [' Amplifying war-related fears', ' Blaming the war on others rather than the invader', ' Discrediting Ukraine', ' Discrediting the West, Diplomacy', ' Distrust towards Media', ' Hidden plots by secret schemes of powerful groups', ' Negative Consequences for the West', ' Overpraising the West', ' Praise of Russia', ' Russia is the Victim', ' Speculating war outcomes']
# 30 [' By continuing the war we risk WWIII', ' Diplomacy does/will not work', ' Discrediting Ukrainian government and officials and policies', ' Discrediting Ukrainian military', ' Discrediting Ukrainian nation and society', ' NATO should/will directly intervene', ' Other', ' Praise of Russian President Vladimir Putin', ' Praise of Russian military might', ' Rewriting Ukraine’s history', ' Russia actions in Ukraine are only self-defence', ' Russia has international support from a number of countries and people', ' Russia is a guarantor of peace and prosperity', ' Russia will also attack other countries', ' Situation in Ukraine is hopeless', ' The EU is divided', ' The West are the aggressors', ' The West does not care about Ukraine, only about its interests', ' The West is overreacting', ' The West is russophobic', ' The West is weak', ' The conflict will increase the Ukrainian refugee flows to Europe', ' There is a real possibility that nuclear weapons will be employed', ' UA is anti-RU extremists', ' Ukraine is a puppet of the West', ' Ukraine is associated with nazism', ' Ukraine is the aggressor', ' Ukrainian army is collapsing', ' Ukrainian media cannot be trusted', ' Western media is an instrument of propaganda']

# %% [markdown]
# ### Articles Embedding

# %%
## Download package for russian
# Install SpaCy and download the Russian model
# !pip install spacy
# !python -m spacy download ru_core_news_sm
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting ru-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.7.0/ru_core_news_sm-3.7.0-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 70.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from ru-core-news-sm==3.7.0) (3.7.5)
# Collecting pymorphy3>=1.0.0 (from ru-core-news-sm==3.7.0)
#   Downloading pymorphy3-2.0.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting dawg-python>=0.7.1 (from pymorphy3>=1.0.0->ru-core-news-sm==3.7.0)
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl.metadata (7.0 kB)
# Collecting pymorphy3-dicts-ru (from pymorphy3>=1.0.0->ru-core-news-sm==3.7.0)
#   Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.1.2)
# Downloading pymorphy3-2.0.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 2.2 MB/s eta 0:00:00
# Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 47.3 MB/s eta 0:00:00
# Installing collected packages: pymorphy3-dicts-ru, dawg-python, pymorphy3, ru-core-news-sm
# Successfully installed dawg-python-0.7.2 pymorphy3-2.0.2 pymorphy3-dicts-ru-2.4.417150.4580142 ru-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# Load SpaCy's Russian model
nlp_ru = spacy.load("ru_core_news_sm")

# Check for CUDA availability
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Load pre-trained XLM-R model and tokenizer
model_name = "xlm-roberta-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name).to(device)  # Ensure model is on the correct device

# Function to extract entities from Russian text
def extract_entities_russian(text):
    """
    Extract entities from Russian text using SpaCy's Russian model.

    Args:
        text (str): Input text in Russian.

    Returns:
        list: A list of (entity, label) tuples.
    """
    doc = nlp_ru(text)
    return [(ent.text, ent.label_) for ent in doc.ents]

# Function to map extracted entities to actants
def map_entities_to_actants_russian(entities):
    """
    Map extracted entities to actants based on their labels.

    Args:
        entities (list): List of tuples (entity, label).

    Returns:
        dict: Dictionary with actants (subject, object, helper, opponent).
    """
    actants = defaultdict(list)
    for ent, label in entities:
        if label == "PER":  # Person -> Subject
            actants["subject"].append(ent)
        elif label in {"LOC", "ORG"}:  # Locations/Organizations -> Object
            actants["object"].append(ent)
        else:
            actants["object"].append(ent)  # Default to object for other types
    return dict(actants)

# Function to convert actants to text format
def actants_to_text(actants):
    """
    Convert actants dictionary to a readable text format.

    Args:
        actants (dict): Dictionary with actants (subject, object, helper, opponent).

    Returns:
        str: Text representation of actants.
    """
    actants_text = []
    if actants.get("subject"):
        actants_text.append(f"Subject: {', '.join(actants['subject'])}.")
    if actants.get("object"):
        actants_text.append(f"Object: {', '.join(actants['object'])}.")
    return " ".join(actants_text)

# Function to compute embeddings using XLM-R
def compute_xlm_r_embedding(text):
    """
    Compute XLM-R embeddings for the given text.

    Args:
        text (str): Input text.

    Returns:
        numpy.ndarray: Embedding vector of the text.
    """
    # Tokenize input text
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512, padding="max_length").to(device)

    # Generate embeddings
    with torch.no_grad():
        outputs = model(**inputs)

    # Token embeddings (last hidden state)
    token_embeddings = outputs.last_hidden_state  # Shape: (batch_size, seq_len, hidden_size)

    # Apply mean pooling to aggregate token embeddings
    attention_mask = inputs['attention_mask']
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, dim=1)
    sum_mask = torch.clamp(input_mask_expanded.sum(dim=1), min=1e-9)
    embedding = sum_embeddings / sum_mask  # Mean pooling

    # Move back to CPU and convert to NumPy
    return embedding.squeeze().cpu().numpy()

# Function to process Russian articles with embeddings
def process_russian_articles_with_embeddings(article_df):
    """
    Process Russian articles to extract actants and compute embeddings.

    Args:
        article_df (pd.DataFrame): DataFrame with article_id and text columns.

    Returns:
        pd.DataFrame: Updated DataFrame with actants and embeddings.
    """
    # Extract entities and map them to actants
    article_df['entities'] = article_df['text'].apply(extract_entities_russian)
    article_df['actants'] = article_df['entities'].apply(map_entities_to_actants_russian)

    # Convert actants to text
    article_df['actants_text'] = article_df['actants'].apply(actants_to_text)

    # Compute embeddings for article text and actant text
    article_df['text_embedding'] = article_df['text'].apply(compute_xlm_r_embedding)
    article_df['actants_embedding'] = article_df['actants_text'].apply(compute_xlm_r_embedding)

    # Combine text and actant embeddings
    article_df['combined_embedding'] = article_df.apply(
        lambda row: np.hstack([row['text_embedding'], row['actants_embedding']]),
        axis=1
    )

    return article_df

## Train and dev aritcles
processed_train_df = process_russian_articles_with_embeddings(train_articles)
processed_dev_df = process_russian_articles_with_embeddings(dev_articles)
# Out:
# Using device: cuda
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]

# %%
processed_train_df.head()
# Out:
#         article_id                                               text  \
# 0  RU-URW-1017.txt  Дмитрий Стешин: Россия тихо глушит GPS европей...
# 1  RU-URW-1021.txt  23:55 Лукашенко обвинил Запад в стремлении к е...
# 2  RU-URW-1031.txt  Лихачев: РФ ждет от ООН оценку действий Киева ...
# 3  RU-URW-1025.txt  Финский наемник Сирен раскритиковал подготовку...
# 4  RU-URW-1011.txt  Если ВС РФ расширят фронт, США позволят Украин...
#
#                                             entities  \
# 0  [(Дмитрий Стешин, PER), (Россия, LOC), (Россия...
# 1  [(Лукашенко, PER), (Запад, LOC), (Украине, LOC...
# 2  [(РФ, LOC), (ООН, ORG), (Киева, LOC), (Энергод...
# 3  [(Сирен, PER), (ВСУ, ORG), (ВСУ, ORG), (Ральф ...
# 4  [(ВС, ORG), (РФ, LOC), (США, LOC), (Украине, L...
#
#                                              actants  \
# 0  {'subject': ['Дмитрий Стешин'], 'object': ['Ро...
# 1  {'subject': ['Лукашенко', 'Александр Лукашенко...
# 2  {'object': ['РФ', 'ООН', 'Киева', 'Энергодаре'...
# 3  {'subject': ['Сирен', 'Ральф Сирен', 'Сирен'],...
# 4  {'object': ['ВС', 'РФ', 'США', 'Украине', 'Рос...
#
#                                         actants_text  \
# 0  Subject: Дмитрий Стешин. Object: Россия, Росси...
# 1  Subject: Лукашенко, Александр Лукашенко, Лукаш...
# 2  Subject: Лихачев, Алексей Лихачев, Лихачев, Ра...
# 3  Subject: Сирен, Ральф Сирен, Сирен. Object: ВС...
# 4  Subject: Джеймс О’Брайен, Джейк Салливан, Джей...
#
#                                       text_embedding  \
# 0  [0.007704131, 0.022058254, -0.007781817, 0.005...
# 1  [0.0068586157, 0.038234632, -0.019731209, 0.02...
# 2  [-0.0023059421, 0.027885303, -0.0032359113, 0....
# 3  [-0.008707507, 0.04932406, -0.021118887, 0.021...
# 4  [-0.0027351298, 0.022900289, -0.010704674, 0.0...
#
#                                    actants_embedding  \
# 0  [0.014929229, 0.054797117, 0.018662047, 0.0155...
# 1  [0.022818657, 0.058647245, 0.016941959, 0.0069...
# 2  [0.019282598, 0.04593163, 0.01878873, 0.002279...
# 3  [0.02719694, 0.0851744, 0.0016649642, 0.037561...
# 4  [0.01587944, 0.04571804, 0.036064718, -0.00617...
#
#                                   combined_embedding
# 0  [0.007704131, 0.022058254, -0.007781817, 0.005...
# 1  [0.0068586157, 0.038234632, -0.019731209, 0.02...
# 2  [-0.0023059421, 0.027885303, -0.0032359113, 0....
# 3  [-0.008707507, 0.04932406, -0.021118887, 0.021...
# 4  [-0.0027351298, 0.022900289, -0.010704674, 0.0...

# %%
processed_dev_df.head()
# Out:
#         article_id                                               text  \
# 0  RU-URW-1120.txt  Военная операция на Украине, день 869-й\n"Служ...
# 1  RU-URW-1043.txt  08:15Главное за ночь 3 июля\nВладимир Путин пр...
# 2  RU-URW-1073.txt  "Украина не готова к компромиссу с Россией рад...
# 3  RU-URW-1014.txt  Алаудинов: российские силы растянули и размыли...
# 4  RU-URW-1023.txt  Для чего Украина провоцирует Белоруссию на вое...
#
#                                             entities  \
# 0  [(Украине, LOC), (Служба внешней разведки (СВР...
# 1  [(Владимир Путин, PER), (Астану, LOC), (ШОС, O...
# 2  [(Украина, LOC), (Россией, LOC), (Офиса презид...
# 3  [(Алаудинов, PER), (ВСУ, ORG), (Харьковской об...
# 4  [(Украина, LOC), (Белоруссию, LOC), (Киев, LOC...
#
#                                              actants  \
# 0  {'object': ['Украине', 'Служба внешней разведк...
# 1  {'subject': ['Владимир Путин', 'Эрдоганом', 'С...
# 2  {'object': ['Украина', 'Россией', 'Офиса прези...
# 3  {'subject': ['Алаудинов', 'Апти Алаудинов'], '...
# 4  {'object': ['Украина', 'Белоруссию', 'Киев', '...
#
#                                         actants_text  \
# 0  Subject: Владимиру Зеленскому, Зеленского, Вал...
# 1  Subject: Владимир Путин, Эрдоганом, Си Цзиньпи...
# 2  Subject: Трампа, Орбану, Ермак, Андрюша. Objec...
# 3  Subject: Алаудинов, Апти Алаудинов. Object: ВС...
# 4  Subject: Константин Сивков. Object: Украина, Б...
#
#                                       text_embedding  \
# 0  [0.024559716, 0.04935156, -0.009897733, 0.0196...
# 1  [0.00015725837, 0.038317386, -0.011712183, 0.0...
# 2  [0.0060347854, 0.03328179, 0.010227945, 0.0223...
# 3  [0.012648377, 0.017662816, -0.013254319, 0.029...
# 4  [-0.0013787227, 0.026964093, -0.0036002013, 0....
#
#                                    actants_embedding  \
# 0  [0.02767332, 0.046520017, 0.019670695, 0.00079...
# 1  [0.0065622046, 0.0566163, 0.022719786, 0.01691...
# 2  [0.023116622, 0.07449146, 0.029456686, 0.03267...
# 3  [0.018034656, 0.071815215, 0.025381723, 0.0336...
# 4  [-0.0070581306, 0.04410064, 0.024095109, 0.012...
#
#                                   combined_embedding
# 0  [0.024559716, 0.04935156, -0.009897733, 0.0196...
# 1  [0.00015725837, 0.038317386, -0.011712183, 0.0...
# 2  [0.0060347854, 0.03328179, 0.010227945, 0.0223...
# 3  [0.012648377, 0.017662816, -0.013254319, 0.029...
# 4  [-0.0013787227, 0.026964093, -0.0036002013, 0....

# %%
# Save processed DataFrames
processed_train_df.to_csv('/content/drive/MyDrive/NLP_Proj/embedded_article/processed_train_rus_articles.csv', index=False)
processed_dev_df.to_csv('/content/drive/MyDrive/NLP_Proj/embedded_article/processed_dev_rus_articles.csv', index=False)

# %% [markdown]
# ### One hot Labels

# %%
def one_hot_encode_hierarchical(df, columns):
    """
    One-hot encode hierarchically related columns in a DataFrame.

    Args:
        df (pd.DataFrame): Input DataFrame with hierarchical columns.
        columns (list): List of column names to encode hierarchically.

    Returns:
        pd.DataFrame: Updated DataFrame with encoded values in new columns.
        dict: Dictionary of mappings for each column.
    """
    encoder = OneHotEncoder(sparse_output=False, dtype=int)
    mappings = {}

    for column in columns:
        # Fit and transform the column
        encoded = encoder.fit_transform(df[[column]])

        # Extract class labels and create a mapping
        class_labels = encoder.categories_[0]
        mapping = {label: idx for idx, label in enumerate(class_labels)}

        # Add the encoded column to the DataFrame
        df[f"{column}_encoded"] = encoded.argmax(axis=1)

        # Save the mapping
        mappings[column] = mapping

    return df, mappings

def encode_dev_with_train_mapping(dev_df, train_mappings, columns):
    """
    Encode the development data using mappings from the training data.

    Args:
        dev_df (pd.DataFrame): Development DataFrame.
        train_mappings (dict): Mappings generated from training data.
        columns (list): List of column names to encode hierarchically.

    Returns:
        pd.DataFrame: Updated development DataFrame with encoded values.
        dict: Updated mappings including any new classes from dev data.
    """
    updated_mappings = train_mappings.copy()

    for column in columns:
        if column not in updated_mappings:
            raise ValueError(f"No mapping found for column {column} in train_mappings.")

        mapping = updated_mappings[column]

        # Check for new classes in dev data
        new_classes = set(dev_df[column].unique()) - set(mapping.keys())
        for cls in new_classes:
            mapping[cls] = len(mapping)

        # Encode the column in dev data
        dev_df[f"{column}_encoded"] = dev_df[column].map(mapping).fillna(-1).astype(int)

        # Update the mappings with new classes
        updated_mappings[column] = mapping

    return dev_df, updated_mappings

def save_mappings(mappings, filepath):
    """
    Save mappings to a JSON file for future use.

    Args:
        mappings (dict): Dictionary of mappings for hierarchical columns.
        filepath (str): Path to save the mappings file.
    """
    with open(filepath, 'w') as f:
        json.dump(mappings, f)
    print(f"Mappings saved to {filepath}")

def load_mappings(filepath):
    """
    Load mappings from a JSON file.

    Args:
        filepath (str): Path to the mappings file.

    Returns:
        dict: Loaded mappings dictionary.
    """
    with open(filepath, 'r') as f:
        mappings = json.load(f)
    return mappings



# Define columns to encode
columns_to_encode = ['narrative', 'level_1', 'level_2']

# Perform one-hot encoding on training annotations
train_encoded, train_mappings = one_hot_encode_hierarchical(expanded_train_annotations, columns_to_encode)

# Perform one-hot encoding on development annotations using train mappings
dev_encoded, updated_mappings = encode_dev_with_train_mapping(expanded_dev_annotations, train_mappings, columns_to_encode)

# Save mappings for future use
save_mappings(updated_mappings, "mappings.json")
# Out:
# Mappings saved to mappings.json

# %%
train_encoded.head()
# Out:
#         article_id narrative                            level_1  \
# 0  RU-URW-1080.txt       URW               Discrediting Ukraine
# 1  RU-URW-1013.txt       URW   Discrediting the West, Diplomacy
# 2  RU-URW-1145.txt       URW                   Praise of Russia
# 3  RU-URW-1048.txt       URW               Discrediting Ukraine
# 4  RU-URW-1001.txt       URW                   Praise of Russia
#
#                                              level_2  narrative_encoded  \
# 0   Discrediting Ukrainian government and officia...                  0
# 1   The West does not care about Ukraine, only ab...                  0
# 2                   Praise of Russian military might                  0
# 3                    Discrediting Ukrainian military                  0
# 4      Russia is a guarantor of peace and prosperity                  0
#
#    level_1_encoded  level_2_encoded
# 0                2                2
# 1                3               17
# 2                8                8
# 3                2                3
# 4                8               12

# %%
dev_encoded.head()
# Out:
#         article_id narrative                            level_1  \
# 0  RU-URW-1135.txt       URW               Russia is the Victim
# 1  RU-URW-1135.txt       URW   Discrediting the West, Diplomacy
# 2  RU-URW-1135.txt       URW   Discrediting the West, Diplomacy
# 3  RU-URW-1089.txt     Other                              Other
# 4  RU-URW-1093.txt       URW               Discrediting Ukraine
#
#                             level_2  narrative_encoded  level_1_encoded  \
# 0           The West is russophobic                  0                9
# 1                 The EU is divided                  0                3
# 2                             Other                  0                3
# 3                             Other                  1               11
# 4   Discrediting Ukrainian military                  0                2
#
#    level_2_encoded
# 0               19
# 1               15
# 2                6
# 3               31
# 4                3

# %%
print(updated_mappings)
# Out:
# {'narrative': {'URW': 0, 'Other': 1}, 'level_1': {' Amplifying war-related fears': 0, ' Blaming the war on others rather than the invader': 1, ' Discrediting Ukraine': 2, ' Discrediting the West, Diplomacy': 3, ' Distrust towards Media': 4, ' Hidden plots by secret schemes of powerful groups': 5, ' Negative Consequences for the West': 6, ' Overpraising the West': 7, ' Praise of Russia': 8, ' Russia is the Victim': 9, ' Speculating war outcomes': 10, 'Other': 11}, 'level_2': {' By continuing the war we risk WWIII': 0, ' Diplomacy does/will not work': 1, ' Discrediting Ukrainian government and officials and policies': 2, ' Discrediting Ukrainian military': 3, ' Discrediting Ukrainian nation and society': 4, ' NATO should/will directly intervene': 5, ' Other': 6, ' Praise of Russian President Vladimir Putin': 7, ' Praise of Russian military might': 8, ' Rewriting Ukraine’s history': 9, ' Russia actions in Ukraine are only self-defence': 10, ' Russia has international support from a number of countries and people': 11, ' Russia is a guarantor of peace and prosperity': 12, ' Russia will also attack other countries': 13, ' Situation in Ukraine is hopeless': 14, ' The EU is divided': 15, ' The West are the aggressors': 16, ' The West does not care about Ukraine, only about its interests': 17, ' The West is overreacting': 18, ' The West is russophobic': 19, ' The West is weak': 20, ' The conflict will increase the Ukrainian refugee flows to Europe': 21, ' There is a real possibility that nuclear weapons will be employed': 22, ' UA is anti-RU extremists': 23, ' Ukraine is a puppet of the West': 24, ' Ukraine is associated with nazism': 25, ' Ukraine is the aggressor': 26, ' Ukrainian army is collapsing': 27, ' Ukrainian media cannot be trusted': 28, ' Western media is an instrument of propaganda': 29, ' Sanctions imposed by Western countries will backfire': 30, 'Other': 31, ' Ukraine is a hub for criminal activities': 32, ' West is tired of Ukraine': 33}}

# %%
# Save processed DataFrame
def save_processed_data(train_df, dev_df, train_path, dev_path):
    train_df.to_csv(train_path, index=False)
    dev_df.to_csv(dev_path, index=False)
    print(f"Train saved to {train_path}")
    print(f"Dev saved to {dev_path}")

save_processed_data(train_encoded, dev_encoded, "/content/drive/MyDrive/NLP_Proj/embedded_article/train_encoded_rus.csv", "/content/drive/MyDrive/NLP_Proj/embedded_article/dev_encoded_rus.csv")
# Out:
# Train saved to /content/drive/MyDrive/NLP_Proj/embedded_article/train_encoded_rus.csv
# Dev saved to /content/drive/MyDrive/NLP_Proj/embedded_article/dev_encoded_rus.csv

# %% [markdown]
# ### Train test split

# %%
# Load processed datasets
processed_train_df = pd.read_csv('/content/drive/MyDrive/NLP_Proj/embedded_article/processed_train_rus_articles.csv')
train_processed = pd.read_csv('/content/drive/MyDrive/NLP_Proj/embedded_article/train_encoded_rus.csv')

processed_dev_df = pd.read_csv('/content/drive/MyDrive/NLP_Proj/embedded_article/processed_dev_rus_articles.csv')
dev_processed = pd.read_csv('/content/drive/MyDrive/NLP_Proj/embedded_article/dev_encoded_rus.csv')

# Merge article embeddings with annotation embeddings
merged_train = pd.merge(
    processed_train_df[['article_id', 'text_embedding', 'actants_embedding']],
    train_processed[['article_id', 'narrative_encoded', 'level_1_encoded', 'level_2_encoded']],
    on='article_id'
)

# Merge article embeddings with annotation embeddings
merged_dev = pd.merge(
    processed_dev_df[['article_id', 'text_embedding', 'actants_embedding']],
    dev_processed[['article_id', 'narrative_encoded', 'level_1_encoded', 'level_2_encoded']],
    on='article_id'
)
merged_dev = merged_dev[merged_dev['narrative_encoded'] != 1]

def string_to_array_embeds(embed_str):
    try:
        # Remove brackets and newline characters, then split into components
        embed_str = embed_str.strip("[]").replace("\n", "")
        # Convert each component to a float and return as a NumPy array
        return np.array([float(x) for x in embed_str.split() if x.strip()])
    except (ValueError, TypeError):
        # Return an empty array if parsing fails
        return np.array([])


def string_to_array(embed_str):
    try:
        # Safely evaluate the string to a Python list
        return np.array(ast.literal_eval(embed_str))
    except (ValueError, SyntaxError, TypeError):
        # Return an empty array if parsing fails
        return np.array([])


merged_train['text_embedding'] = merged_train['text_embedding'].apply(string_to_array_embeds)
merged_train['actants_embedding'] = merged_train['actants_embedding'].apply(string_to_array_embeds)

merged_dev['text_embedding'] = merged_dev['text_embedding'].apply(string_to_array_embeds)
merged_dev['actants_embedding'] = merged_dev['actants_embedding'].apply(string_to_array_embeds)

#merged_train.head()

# Pad or truncate arrays to the maximum length
def pad_or_truncate(array, target_length):
    if len(array) < target_length:
        return np.pad(array, (0, target_length - len(array)), mode='constant')
    elif len(array) > target_length:
        return array[:target_length]
    return array

# Find maximum lengths for padding
max_sentence_length = max(
    max(merged_train['text_embedding'].apply(len), default=0),
    max(merged_dev['text_embedding'].apply(len), default=0)
)

max_actants_length = max(
    max(merged_train['actants_embedding'].apply(len), default=0),
    max(merged_dev['actants_embedding'].apply(len), default=0)
)

# Pad embeddings for sentence and actants
for df in [merged_train, merged_dev]:
    df['text_embedding'] = df['text_embedding'].apply(lambda x: pad_or_truncate(x, max_sentence_length))
    df['actants_embedding'] = df['actants_embedding'].apply(lambda x: pad_or_truncate(x, max_actants_length))


# Count the number of samples per class for `level_1_encoded`
class_counts = merged_dev['level_1_encoded'].value_counts()

# Filter out classes with fewer than 2 samples
valid_classes = class_counts[class_counts >= 2].index
filtered_dev = merged_dev[merged_dev['level_1_encoded'].isin(valid_classes)]

print(f"Filtered dataset size: {filtered_train.shape}")
print(f"Remaining classes: {len(valid_classes)}")

# Perform stratified splitting
validation_df, test_df = train_test_split(
    filtered_dev,
    test_size=0.5,
    stratify=filtered_dev['level_1_encoded'],
    random_state=42
)


# Prepare training and validation splits
X_train = np.hstack([
    np.vstack(merged_train['text_embedding']),
    np.vstack(merged_train['actants_embedding']),
])

y_train = merged_train[['level_1_encoded', 'level_2_encoded']].to_dict(orient='list')

X_val = np.hstack([
    np.vstack(validation_df['text_embedding']),
    np.vstack(validation_df['actants_embedding']),
])

y_val = validation_df[['level_1_encoded', 'level_2_encoded']].to_dict(orient='list')

# Prepare test splits
X_test = np.hstack([
    np.vstack(test_df['text_embedding']),
    np.vstack(test_df['actants_embedding']),
])

y_test = test_df[['level_1_encoded', 'level_2_encoded']].to_dict(orient='list')

# Print updated train-validation-test split details
print(f"Train: X_train: {X_train.shape}, y_train: {[len(y) for y in y_train.values()]}")
print(f"Validation: X_val: {X_val.shape}, y_val: {[len(y) for y in y_val.values()]}")
print(f"Test: X_test: {X_test.shape}, y_test: {[len(y) for y in y_test.values()]}")
# Out:
# Filtered dataset size: (73, 6)
# Remaining classes: 8
# Train: X_train: (272, 1536), y_train: [272, 272]
# Validation: X_val: (36, 1536), y_val: [36, 36]
# Test: X_test: (37, 1536), y_test: [37, 37]

# %%
print(len(np.unique(merged_train['level_1_encoded'])))
print(len(np.unique(merged_train['level_2_encoded'])))

# Calculate the max and min values for level_1_encoded
max_value = merged_dev['level_2_encoded'].max()
min_value = merged_dev['level_2_encoded'].min()

# Print the results
print(f"Maximum value in level_2_encoded: {max_value}")
print(f"Minimum value in level_2_encoded: {min_value}")
# Out:
# 11
# 30
# Maximum value in level_2_encoded: 33
# Minimum value in level_2_encoded: 1

# %% [markdown]
# ### Modelling

# %%
import tensorflow as tf
from tensorflow.keras.layers import (
    Input, Dense, Dropout, Concatenate, Add, BatchNormalization, Activation
)
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# Transformer-based hierarchical model
def create_hierarchical_model(input_dim, level_1_classes, level_2_classes):
    # Input Layer
    input_layer = Input(shape=(input_dim,), name="input_layer")

    # Shared Dense Layer 1 (Residual Block)
    shared_dense_1 = Dense(
        512, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.01)
    )(input_layer)
    shared_dense_1 = BatchNormalization()(shared_dense_1)
    shared_dense_1 = Dropout(0.5)(shared_dense_1)
    residual_1 = Dense(512, activation="relu")(shared_dense_1)  # Residual connection
    residual_1 = Add()([shared_dense_1, residual_1])

    # Shared Dense Layer 2 (Residual Block)
    shared_dense_2 = Dense(
        256, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.01)
    )(residual_1)
    shared_dense_2 = BatchNormalization()(shared_dense_2)
    shared_dense_2 = Dropout(0.5)(shared_dense_2)
    residual_2 = Dense(256, activation="relu")(shared_dense_2)  # Residual connection
    residual_2 = Add()([shared_dense_2, residual_2])

    # Level 1 Classifier (Parent)
    level_1_output = Dense(
        level_1_classes, activation="softmax", name="level_1_output"
    )(residual_2)

    # Concatenate Level 1 predictions with shared embeddings for Level 2
    concatenated_features = Concatenate()([residual_2, level_1_output])

    # Level 2 Dense Layers (Enhanced with Residuals)
    level_2_dense_1 = Dense(
        256, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.01)
    )(concatenated_features)
    level_2_dense_1 = BatchNormalization()(level_2_dense_1)
    level_2_dense_1 = Dropout(0.5)(level_2_dense_1)
    level_2_residual = Dense(256, activation="relu")(level_2_dense_1)  # Residual
    level_2_residual = Add()([level_2_dense_1, level_2_residual])

    # Final Dense Layer for Level 2
    level_2_dense_2 = Dense(
        128, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.01)
    )(level_2_residual)
    level_2_dense_2 = Dropout(0.5)(level_2_dense_2)

    # Level 2 Classifier (Child)
    level_2_output = Dense(
        level_2_classes, activation="softmax", name="level_2_output"
    )(level_2_dense_2)

    # Create Model
    model = Model(inputs=input_layer, outputs=[level_1_output, level_2_output])
    return model


# Create the model
input_dim = X_train.shape[1]
level_1_classes = 11
level_2_classes = 34

model = create_hierarchical_model(input_dim, level_1_classes, level_2_classes)
def dynamic_loss_weights(epoch):
    # Gradually increase Level 2 focus
    if epoch < 10:
        return {"level_1_output": 0.7, "level_2_output": 1.3}
    elif epoch < 20:
        return {"level_1_output": 0.5, "level_2_output": 1.5}
    else:
        return {"level_1_output": 0.3, "level_2_output": 1.7}



# Prepare y_train for hierarchical classification
y_train_level_1_onehot = to_categorical(y_train['level_1_encoded'], num_classes=level_1_classes)
y_train_level_2_onehot = to_categorical(y_train['level_2_encoded'], num_classes=level_2_classes)

y_val_level_1_onehot = to_categorical(y_val['level_1_encoded'], num_classes=level_1_classes)
y_val_level_2_onehot = to_categorical(y_val['level_2_encoded'], num_classes=level_2_classes)

y_test_level_1_onehot = to_categorical(y_test['level_1_encoded'], num_classes=level_1_classes)
y_test_level_2_onehot = to_categorical(y_test['level_2_encoded'], num_classes=level_2_classes)


# Define callbacks for better training performance
early_stopping = EarlyStopping(
    monitor="val_loss", patience=8, restore_best_weights=True, verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6, verbose=1
)

# Training
for epoch in range(2):
    weights = dynamic_loss_weights(epoch)
    model.compile(
        optimizer=tf.keras.optimizers.AdamW(learning_rate=1e-4),
        loss_weights=weights,
        loss={"level_1_output": "categorical_crossentropy", "level_2_output": "categorical_crossentropy"},
        metrics=["accuracy", "accuracy"],
    )
    history = model.fit(
        X_train,
        {"level_1_output": y_train_level_1_onehot, "level_2_output": y_train_level_2_onehot},
        validation_data=(
            X_val,
            {"level_1_output": y_val_level_1_onehot, "level_2_output": y_val_level_2_onehot},
        ),
        batch_size=32,
        epochs=50,
        callbacks=[early_stopping, reduce_lr],
        verbose=1,
    )
# Out:
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 19s 652ms/step - level_1_output_accuracy: 0.0824 - level_1_output_loss: 4.5550 - level_2_output_accuracy: 0.0158 - level_2_output_loss: 6.0776 - loss: 26.4724 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 3.4683 - val_level_2_output_accuracy: 0.0000e+00 - val_level_2_output_loss: 3.9133 - val_loss: 22.8598 - learning_rate: 1.0000e-04
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - level_1_output_accuracy: 0.0603 - level_1_output_loss: 4.5524 - level_2_output_accuracy: 0.0474 - level_2_output_loss: 5.6111 - loss: 25.6810 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 3.2727 - val_level_2_output_accuracy: 0.0000e+00 - val_level_2_output_loss: 3.8187 - val_loss: 22.4211 - learning_rate: 1.0000e-04
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.0629 - level_1_output_loss: 4.1927 - level_2_output_accuracy: 0.0089 - level_2_output_loss: 5.9538 - loss: 25.7102 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 3.1265 - val_level_2_output_accuracy: 0.0556 - val_level_2_output_loss: 3.7416 - val_loss: 22.0446 - learning_rate: 1.0000e-04
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - level_1_output_accuracy: 0.1077 - level_1_output_loss: 3.8976 - level_2_output_accuracy: 0.0381 - level_2_output_loss: 5.6874 - loss: 25.0111 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.9899 - val_level_2_output_accuracy: 0.0556 - val_level_2_output_loss: 3.6880 - val_loss: 21.7194 - learning_rate: 1.0000e-04
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.1197 - level_1_output_loss: 3.7398 - level_2_output_accuracy: 0.0255 - level_2_output_loss: 5.4971 - loss: 24.4953 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.8693 - val_level_2_output_accuracy: 0.0833 - val_level_2_output_loss: 3.6144 - val_loss: 21.4259 - learning_rate: 1.0000e-04
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.1139 - level_1_output_loss: 3.6477 - level_2_output_accuracy: 0.0283 - level_2_output_loss: 5.3589 - loss: 24.1151 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.7630 - val_level_2_output_accuracy: 0.0556 - val_level_2_output_loss: 3.5751 - val_loss: 21.1676 - learning_rate: 1.0000e-04
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.1731 - level_1_output_loss: 3.5078 - level_2_output_accuracy: 0.0697 - level_2_output_loss: 4.9328 - loss: 23.3099 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.6696 - val_level_2_output_accuracy: 0.0833 - val_level_2_output_loss: 3.5316 - val_loss: 20.9143 - learning_rate: 1.0000e-04
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.1338 - level_1_output_loss: 3.2627 - level_2_output_accuracy: 0.0304 - level_2_output_loss: 4.9200 - loss: 22.9901 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.6031 - val_level_2_output_accuracy: 0.0278 - val_level_2_output_loss: 3.4972 - val_loss: 20.6979 - learning_rate: 1.0000e-04
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.1332 - level_1_output_loss: 3.3776 - level_2_output_accuracy: 0.0373 - level_2_output_loss: 4.5606 - loss: 22.4883 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.5375 - val_level_2_output_accuracy: 0.0000e+00 - val_level_2_output_loss: 3.4700 - val_loss: 20.5035 - learning_rate: 1.0000e-04
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.2148 - level_1_output_loss: 3.3407 - level_2_output_accuracy: 0.0298 - level_2_output_loss: 5.0875 - loss: 23.0181 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.4928 - val_level_2_output_accuracy: 0.0000e+00 - val_level_2_output_loss: 3.4479 - val_loss: 20.3344 - learning_rate: 1.0000e-04
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - level_1_output_accuracy: 0.1456 - level_1_output_loss: 3.1497 - level_2_output_accuracy: 0.0649 - level_2_output_loss: 4.5190 - loss: 22.0417 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.4607 - val_level_2_output_accuracy: 0.0000e+00 - val_level_2_output_loss: 3.4394 - val_loss: 20.1889 - learning_rate: 1.0000e-04
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.2476 - level_1_output_loss: 3.1241 - level_2_output_accuracy: 0.0670 - level_2_output_loss: 4.7464 - loss: 22.2060 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.4311 - val_level_2_output_accuracy: 0.0000e+00 - val_level_2_output_loss: 3.4226 - val_loss: 20.0442 - learning_rate: 1.0000e-04
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - level_1_output_accuracy: 0.2467 - level_1_output_loss: 2.8150 - level_2_output_accuracy: 0.0897 - level_2_output_loss: 4.4091 - loss: 21.4416 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.4101 - val_level_2_output_accuracy: 0.0000e+00 - val_level_2_output_loss: 3.3980 - val_loss: 19.9124 - learning_rate: 1.0000e-04
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.1326 - level_1_output_loss: 3.2663 - level_2_output_accuracy: 0.0445 - level_2_output_loss: 4.8130 - loss: 22.1958 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.3918 - val_level_2_output_accuracy: 0.0000e+00 - val_level_2_output_loss: 3.3797 - val_loss: 19.7814 - learning_rate: 1.0000e-04
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.2659 - level_1_output_loss: 2.7415 - level_2_output_accuracy: 0.0722 - level_2_output_loss: 4.5507 - loss: 21.3881 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.3748 - val_level_2_output_accuracy: 0.0278 - val_level_2_output_loss: 3.3543 - val_loss: 19.6562 - learning_rate: 1.0000e-04
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.2122 - level_1_output_loss: 2.9460 - level_2_output_accuracy: 0.0761 - level_2_output_loss: 4.4251 - loss: 21.2695 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.3698 - val_level_2_output_accuracy: 0.0278 - val_level_2_output_loss: 3.3280 - val_loss: 19.5445 - learning_rate: 1.0000e-04
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - level_1_output_accuracy: 0.2705 - level_1_output_loss: 2.5901 - level_2_output_accuracy: 0.0721 - level_2_output_loss: 4.5402 - loss: 21.0956 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.3559 - val_level_2_output_accuracy: 0.0278 - val_level_2_output_loss: 3.3134 - val_loss: 19.4413 - learning_rate: 1.0000e-04
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - level_1_output_accuracy: 0.2624 - level_1_output_loss: 2.6509 - level_2_output_accuracy: 0.0694 - level_2_output_loss: 4.5183 - loss: 21.0122 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.3414 - val_level_2_output_accuracy: 0.0278 - val_level_2_output_loss: 3.3119 - val_loss: 19.3474 - learning_rate: 1.0000e-04
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - level_1_output_accuracy: 0.2469 - level_1_output_loss: 2.7161 - level_2_output_accuracy: 0.0805 - level_2_output_loss: 4.3431 - loss: 20.7520 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.3226 - val_level_2_output_accuracy: 0.0833 - val_level_2_output_loss: 3.3066 - val_loss: 19.2544 - learning_rate: 1.0000e-04
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - level_1_output_accuracy: 0.3092 - level_1_output_loss: 2.5511 - level_2_output_accuracy: 0.0876 - level_2_output_loss: 4.2149 - loss: 20.3948 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.3099 - val_level_2_output_accuracy: 0.0278 - val_level_2_output_loss: 3.3034 - val_loss: 19.1736 - learning_rate: 1.0000e-04
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.3154 - level_1_output_loss: 2.5936 - level_2_output_accuracy: 0.0900 - level_2_output_loss: 4.2206 - loss: 20.3491 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.2980 - val_level_2_output_accuracy: 0.0278 - val_level_2_output_loss: 3.2961 - val_loss: 19.0897 - learning_rate: 1.0000e-04
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.2799 - level_1_output_loss: 2.7236 - level_2_output_accuracy: 0.0627 - level_2_output_loss: 4.2523 - loss: 20.3987 - val_level_1_output_accuracy: 0.0833 - val_level_1_output_loss: 2.2849 - val_level_2_output_accuracy: 0.0556 - val_level_2_output_loss: 3.2869 - val_loss: 19.0070 - learning_rate: 1.0000e-04
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - level_1_output_accuracy: 0.2982 - level_1_output_loss: 2.6560 - level_2_output_accuracy: 0.0615 - level_2_output_loss: 4.2991 - loss: 20.3734 - val_level_1_output_accuracy: 0.0833 - val_level_1_output_loss: 2.2806 - val_level_2_output_accuracy: 0.0556 - val_level_2_output_loss: 3.2760 - val_loss: 18.9256 - learning_rate: 1.0000e-04
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - level_1_output_accuracy: 0.3562 - level_1_output_loss: 2.2213 - level_2_output_accuracy: 0.1082 - level_2_output_loss: 4.0582 - loss: 19.6603 - val_level_1_output_accuracy: 0.1667 - val_level_1_output_loss: 2.2700 - val_level_2_output_accuracy: 0.0556 - val_level_2_output_loss: 3.2612 - val_loss: 18.8361 - learning_rate: 1.0000e-04
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.2862 - level_1_output_loss: 2.4768 - level_2_output_accuracy: 0.0867 - level_2_output_loss: 4.2329 - loss: 20.0212 - val_level_1_output_accuracy: 0.1389 - val_level_1_output_loss: 2.2721 - val_level_2_output_accuracy: 0.0556 - val_level_2_output_loss: 3.2503 - val_loss: 18.7642 - learning_rate: 1.0000e-04
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - level_1_output_accuracy: 0.3305 - level_1_output_loss: 2.1993 - level_2_output_accuracy: 0.0792 - level_2_output_loss: 3.8601 - loss: 19.2765 - val_level_1_output_accuracy: 0.2222 - val_level_1_output_loss: 2.2705 - val_level_2_output_accuracy: 0.0556 - val_level_2_output_loss: 3.2227 - val_loss: 18.6811 - learning_rate: 1.0000e-04
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - level_1_output_accuracy: 0.3125 - level_1_output_loss: 2.2915 - level_2_output_accuracy: 0.1302 - level_2_output_loss: 3.8592 - loss: 19.2904 - val_level_1_output_accuracy: 0.2222 - val_level_1_output_loss: 2.2747 - val_level_2_output_accuracy: 0.0833 - val_level_2_output_loss: 3.1966 - val_loss: 18.6109 - learning_rate: 1.0000e-04
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.3473 - level_1_output_loss: 2.5863 - level_2_output_accuracy: 0.0887 - level_2_output_loss: 3.8654 - loss: 19.4277 - val_level_1_output_accuracy: 0.1944 - val_level_1_output_loss: 2.2998 - val_level_2_output_accuracy: 0.0833 - val_level_2_output_loss: 3.1796 - val_loss: 18.5598 - learning_rate: 1.0000e-04
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - level_1_output_accuracy: 0.3487 - level_1_output_loss: 2.4515 - level_2_output_accuracy: 0.1115 - level_2_output_loss: 3.8714 - loss: 19.3102 - val_level_1_output_accuracy: 0.1667 - val_level_1_output_loss: 2.3255 - val_level_2_output_accuracy: 0.0833 - val_level_2_output_loss: 3.1699 - val_loss: 18.4992 - learning_rate: 1.0000e-04
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.3368 - level_1_output_loss: 2.3943 - level_2_output_accuracy: 0.0640 - level_2_output_loss: 4.0273 - loss: 19.4207 - val_level_1_output_accuracy: 0.1667 - val_level_1_output_loss: 2.3476 - val_level_2_output_accuracy: 0.1111 - val_level_2_output_loss: 3.1696 - val_loss: 18.4524 - learning_rate: 1.0000e-04
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.3106 - level_1_output_loss: 2.4398 - level_2_output_accuracy: 0.0838 - level_2_output_loss: 3.9635 - loss: 19.3065 - val_level_1_output_accuracy: 0.1944 - val_level_1_output_loss: 2.3748 - val_level_2_output_accuracy: 0.1389 - val_level_2_output_loss: 3.1568 - val_loss: 18.4147 - learning_rate: 1.0000e-04
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - level_1_output_accuracy: 0.3568 - level_1_output_loss: 2.2306 - level_2_output_accuracy: 0.1168 - level_2_output_loss: 3.6827 - loss: 18.7467 - val_level_1_output_accuracy: 0.1667 - val_level_1_output_loss: 2.3819 - val_level_2_output_accuracy: 0.1667 - val_level_2_output_loss: 3.1455 - val_loss: 18.3711 - learning_rate: 1.0000e-04
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - level_1_output_accuracy: 0.3746 - level_1_output_loss: 2.1361 - level_2_output_accuracy: 0.1261 - level_2_output_loss: 3.7326 - loss: 18.7081 - val_level_1_output_accuracy: 0.1389 - val_level_1_output_loss: 2.3818 - val_level_2_output_accuracy: 0.1667 - val_level_2_output_loss: 3.1260 - val_loss: 18.3190 - learning_rate: 1.0000e-04
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - level_1_output_accuracy: 0.3039 - level_1_output_loss: 2.5632 - level_2_output_accuracy: 0.1089 - level_2_output_loss: 3.7951 - loss: 19.0294 - val_level_1_output_accuracy: 0.1111 - val_level_1_output_loss: 2.3871 - val_level_2_output_accuracy: 0.1667 - val_level_2_output_loss: 3.1081 - val_loss: 18.2712 - learning_rate: 1.0000e-04
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - level_1_output_accuracy: 0.3428 - level_1_output_loss: 2.2726 - level_2_output_accuracy: 0.1268 - level_2_output_loss: 3.8768 - loss: 18.8892 - val_level_1_output_accuracy: 0.0833 - val_level_1_output_loss: 2.3873 - val_level_2_output_accuracy: 0.1667 - val_level_2_output_loss: 3.0907 - val_loss: 18.2198 - learning_rate: 1.0000e-04
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - level_1_output_accuracy: 0.3504 - level_1_output_loss: 2.2232 - level_2_output_accuracy: 0.1110 - level_2_output_loss: 3.6537 - loss: 18.5308 - val_level_1_output_accuracy: 0.0833 - val_level_1_output_loss: 2.4219 - val_level_2_output_accuracy: 0.1944 - val_level_2_output_loss: 3.0748 - val_loss: 18.1878 - learning_rate: 1.0000e-04
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - level_1_output_accuracy: 0.4264 - level_1_output_loss: 1.9108 - level_2_output_accuracy: 0.1513 - level_2_output_loss: 3.5886 - loss: 18.1938 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.4467 - val_level_2_output_accuracy: 0.1944 - val_level_2_output_loss: 3.0609 - val_loss: 18.1535 - learning_rate: 1.0000e-04
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - level_1_output_accuracy: 0.3519 - level_1_output_loss: 2.3058 - level_2_output_accuracy: 0.1487 - level_2_output_loss: 3.3182 - loss: 18.0672 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.4358 - val_level_2_output_accuracy: 0.1944 - val_level_2_output_loss: 3.0612 - val_loss: 18.0948 - learning_rate: 1.0000e-04
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - level_1_output_accuracy: 0.3689 - level_1_output_loss: 2.1756 - level_2_output_accuracy: 0.1576 - level_2_output_loss: 3.6212 - loss: 18.3393 - val_level_1_output_accuracy: 0.0556 - val_level_1_output_loss: 2.4309 - val_level_2_output_accuracy: 0.1667 - val_level_2_output_loss: 3.0616 - val_loss: 18.0576 - learning_rate: 1.0000e-04
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - level_1_output_accuracy: 0.4060 - level_1_output_loss: 2.0597 - level_2_output_accuracy: 0.1405 - level_2_output_loss: 3.6403 - loss: 18.2429 - val_level_1_output_accuracy: 0.0833 - val_level_1_output_loss: 2.4410 - val_level_2_output_accuracy: 0.1667 - val_level_2_output_loss: 3.0664 - val_loss: 18.0329 - learning_rate: 1.0000e-04
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - level_1_output_accuracy: 0.3864 - level_1_output_loss: 2.0930 - level_2_output_accuracy: 0.1351 - level_2_output_loss: 3.5824 - loss: 18.1584 - val_level_1_output_accuracy: 0.0833 - val_level_1_output_loss: 2.4454 - val_level_2_output_accuracy: 0.1944 - val_level_2_output_loss: 3.0416 - val_loss: 17.9948 - learning_rate: 1.0000e-04
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - level_1_output_accuracy: 0.4203 - level_1_output_loss: 1.9394 - level_2_output_accuracy: 0.1637 - level_2_output_loss: 3.4319 - loss: 17.8147 - val_level_1_output_accuracy: 0.1389 - val_level_1_output_loss: 2.4425 - val_level_2_output_accuracy: 0.1944 - val_level_2_output_loss: 3.0192 - val_loss: 17.9377 - learning_rate: 1.0000e-04
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - level_1_output_accuracy: 0.3536 - level_1_output_loss: 2.1833 - level_2_output_accuracy: 0.0738 - level_2_output_loss: 3.8265 - loss: 18.4703 - val_level_1_output_accuracy: 0.1944 - val_level_1_output_loss: 2.4298 - val_level_2_output_accuracy: 0.1667 - val_level_2_output_loss: 3.0147 - val_loss: 17.8827 - learning_rate: 1.0000e-04
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - level_1_output_accuracy: 0.3662 - level_1_output_loss: 2.1785 - level_2_output_accuracy: 0.1899 - level_2_output_loss: 3.2737 - loss: 17.7183 - val_level_1_output_accuracy: 0.1944 - val_level_1_output_loss: 2.4381 - val_level_2_output_accuracy: 0.1667 - val_level_2_output_loss: 3.0076 - val_loss: 17.8820 - learning_rate: 1.0000e-04
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.4396 - level_1_output_loss: 1.7846 - level_2_output_accuracy: 0.1003 - level_2_output_loss: 3.3843 - loss: 17.5605 - val_level_1_output_accuracy: 0.1389 - val_level_1_output_loss: 2.4696 - val_level_2_output_accuracy: 0.1111 - val_level_2_output_loss: 3.0148 - val_loss: 17.8801 - learning_rate: 1.0000e-04
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - level_1_output_accuracy: 0.3661 - level_1_output_loss: 2.2143 - level_2_output_accuracy: 0.1098 - level_2_output_loss: 3.6575 - loss: 18.1916 - val_level_1_output_accuracy: 0.1111 - val_level_1_output_loss: 2.4955 - val_level_2_output_accuracy: 0.1111 - val_level_2_output_loss: 3.0116 - val_loss: 17.8506 - learning_rate: 1.0000e-04
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.4197 - level_1_output_loss: 2.1191 - level_2_output_accuracy: 0.1149 - level_2_output_loss: 3.7727 - loss: 18.2355 - val_level_1_output_accuracy: 0.1111 - val_level_1_output_loss: 2.5169 - val_level_2_output_accuracy: 0.1389 - val_level_2_output_loss: 3.0225 - val_loss: 17.8315 - learning_rate: 1.0000e-04
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - level_1_output_accuracy: 0.4221 - level_1_output_loss: 1.9970 - level_2_output_accuracy: 0.1818 - level_2_output_loss: 3.4434 - loss: 17.7006 - val_level_1_output_accuracy: 0.1389 - val_level_1_output_loss: 2.5306 - val_level_2_output_accuracy: 0.1389 - val_level_2_output_loss: 3.0270 - val_loss: 17.8151 - learning_rate: 1.0000e-04
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - level_1_output_accuracy: 0.4137 - level_1_output_loss: 1.8818 - level_2_output_accuracy: 0.1334 - level_2_output_loss: 3.4037 - loss: 17.5354 - val_level_1_output_accuracy: 0.1389 - val_level_1_output_loss: 2.5250 - val_level_2_output_accuracy: 0.1389 - val_level_2_output_loss: 3.0348 - val_loss: 17.7789 - learning_rate: 1.0000e-04
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.4105 - level_1_output_loss: 1.8853 - level_2_output_accuracy: 0.1420 - level_2_output_loss: 3.3974 - loss: 17.4998 - val_level_1_output_accuracy: 0.1389 - val_level_1_output_loss: 2.5471 - val_level_2_output_accuracy: 0.1111 - val_level_2_output_loss: 3.0313 - val_loss: 17.7567 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 50.
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 15s 821ms/step - level_1_output_accuracy: 0.3969 - level_1_output_loss: 2.0458 - level_2_output_accuracy: 0.1485 - level_2_output_loss: 3.4724 - loss: 17.6789 - val_level_1_output_accuracy: 0.1389 - val_level_1_output_loss: 2.5858 - val_level_2_output_accuracy: 0.1111 - val_level_2_output_loss: 3.0297 - val_loss: 17.7090 - learning_rate: 1.0000e-04
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - level_1_output_accuracy: 0.3941 - level_1_output_loss: 1.8753 - level_2_output_accuracy: 0.1365 - level_2_output_loss: 3.3886 - loss: 17.4010 - val_level_1_output_accuracy: 0.1389 - val_level_1_output_loss: 2.5786 - val_level_2_output_accuracy: 0.0833 - val_level_2_output_loss: 2.9982 - val_loss: 17.6356 - learning_rate: 1.0000e-04
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.4284 - level_1_output_loss: 1.9119 - level_2_output_accuracy: 0.0823 - level_2_output_loss: 3.5478 - loss: 17.5750 - val_level_1_output_accuracy: 0.1389 - val_level_1_output_loss: 2.5183 - val_level_2_output_accuracy: 0.1111 - val_level_2_output_loss: 2.9876 - val_loss: 17.5309 - learning_rate: 1.0000e-04
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - level_1_output_accuracy: 0.4380 - level_1_output_loss: 1.7201 - level_2_output_accuracy: 0.1300 - level_2_output_loss: 3.5455 - loss: 17.3848 - val_level_1_output_accuracy: 0.1944 - val_level_1_output_loss: 2.4642 - val_level_2_output_accuracy: 0.1111 - val_level_2_output_loss: 2.9693 - val_loss: 17.4106 - learning_rate: 1.0000e-04
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.4320 - level_1_output_loss: 1.9901 - level_2_output_accuracy: 0.1515 - level_2_output_loss: 3.3543 - loss: 17.2732 - val_level_1_output_accuracy: 0.2222 - val_level_1_output_loss: 2.4098 - val_level_2_output_accuracy: 0.1111 - val_level_2_output_loss: 2.9061 - val_loss: 17.2824 - learning_rate: 1.0000e-04
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.4277 - level_1_output_loss: 1.8327 - level_2_output_accuracy: 0.1155 - level_2_output_loss: 3.6544 - loss: 17.5359 - val_level_1_output_accuracy: 0.2500 - val_level_1_output_loss: 2.4182 - val_level_2_output_accuracy: 0.1111 - val_level_2_output_loss: 2.8834 - val_loss: 17.2082 - learning_rate: 1.0000e-04
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.4285 - level_1_output_loss: 1.8706 - level_2_output_accuracy: 0.1551 - level_2_output_loss: 3.3225 - loss: 17.0933 - val_level_1_output_accuracy: 0.2500 - val_level_1_output_loss: 2.4032 - val_level_2_output_accuracy: 0.1389 - val_level_2_output_loss: 2.8529 - val_loss: 17.1343 - learning_rate: 1.0000e-04
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.4544 - level_1_output_loss: 1.8210 - level_2_output_accuracy: 0.1624 - level_2_output_loss: 3.3491 - loss: 17.0456 - val_level_1_output_accuracy: 0.2500 - val_level_1_output_loss: 2.3461 - val_level_2_output_accuracy: 0.1667 - val_level_2_output_loss: 2.8509 - val_loss: 17.0459 - learning_rate: 1.0000e-04
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.3596 - level_1_output_loss: 1.8926 - level_2_output_accuracy: 0.1416 - level_2_output_loss: 3.3441 - loss: 17.0754 - val_level_1_output_accuracy: 0.3333 - val_level_1_output_loss: 2.3390 - val_level_2_output_accuracy: 0.1944 - val_level_2_output_loss: 2.8514 - val_loss: 17.0148 - learning_rate: 1.0000e-04
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - level_1_output_accuracy: 0.4043 - level_1_output_loss: 1.9564 - level_2_output_accuracy: 0.1398 - level_2_output_loss: 3.3587 - loss: 17.0985 - val_level_1_output_accuracy: 0.3333 - val_level_1_output_loss: 2.3505 - val_level_2_output_accuracy: 0.1944 - val_level_2_output_loss: 2.8638 - val_loss: 17.0079 - learning_rate: 1.0000e-04
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.4405 - level_1_output_loss: 1.8869 - level_2_output_accuracy: 0.1314 - level_2_output_loss: 3.3435 - loss: 17.0111 - val_level_1_output_accuracy: 0.3333 - val_level_1_output_loss: 2.2993 - val_level_2_output_accuracy: 0.1944 - val_level_2_output_loss: 2.8616 - val_loss: 16.9555 - learning_rate: 1.0000e-04
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.4772 - level_1_output_loss: 1.7036 - level_2_output_accuracy: 0.1028 - level_2_output_loss: 3.5689 - loss: 17.1363 - val_level_1_output_accuracy: 0.3333 - val_level_1_output_loss: 2.2756 - val_level_2_output_accuracy: 0.1944 - val_level_2_output_loss: 2.8392 - val_loss: 16.9003 - learning_rate: 1.0000e-04
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.4037 - level_1_output_loss: 2.0159 - level_2_output_accuracy: 0.1480 - level_2_output_loss: 3.3367 - loss: 17.0457 - val_level_1_output_accuracy: 0.2778 - val_level_1_output_loss: 2.3070 - val_level_2_output_accuracy: 0.1667 - val_level_2_output_loss: 2.8354 - val_loss: 16.8320 - learning_rate: 1.0000e-04
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.4410 - level_1_output_loss: 1.9135 - level_2_output_accuracy: 0.1636 - level_2_output_loss: 3.3868 - loss: 17.0060 - val_level_1_output_accuracy: 0.2222 - val_level_1_output_loss: 2.3400 - val_level_2_output_accuracy: 0.1667 - val_level_2_output_loss: 2.7765 - val_loss: 16.7752 - learning_rate: 1.0000e-04
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - level_1_output_accuracy: 0.4188 - level_1_output_loss: 1.6869 - level_2_output_accuracy: 0.1762 - level_2_output_loss: 3.2917 - loss: 16.7100 - val_level_1_output_accuracy: 0.1944 - val_level_1_output_loss: 2.3446 - val_level_2_output_accuracy: 0.1944 - val_level_2_output_loss: 2.7808 - val_loss: 16.7273 - learning_rate: 1.0000e-04
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.4864 - level_1_output_loss: 1.5710 - level_2_output_accuracy: 0.1804 - level_2_output_loss: 3.4030 - loss: 16.7454 - val_level_1_output_accuracy: 0.2222 - val_level_1_output_loss: 2.2568 - val_level_2_output_accuracy: 0.1944 - val_level_2_output_loss: 2.7858 - val_loss: 16.6702 - learning_rate: 1.0000e-04
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.4782 - level_1_output_loss: 1.6817 - level_2_output_accuracy: 0.1652 - level_2_output_loss: 3.2691 - loss: 16.6158 - val_level_1_output_accuracy: 0.2500 - val_level_1_output_loss: 2.2434 - val_level_2_output_accuracy: 0.1944 - val_level_2_output_loss: 2.8091 - val_loss: 16.6379 - learning_rate: 1.0000e-04
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.4450 - level_1_output_loss: 1.7619 - level_2_output_accuracy: 0.2098 - level_2_output_loss: 3.1187 - loss: 16.4486 - val_level_1_output_accuracy: 0.2500 - val_level_1_output_loss: 2.1998 - val_level_2_output_accuracy: 0.1667 - val_level_2_output_loss: 2.7873 - val_loss: 16.5892 - learning_rate: 1.0000e-04
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.4381 - level_1_output_loss: 1.7731 - level_2_output_accuracy: 0.1680 - level_2_output_loss: 3.1927 - loss: 16.5562 - val_level_1_output_accuracy: 0.3333 - val_level_1_output_loss: 2.2178 - val_level_2_output_accuracy: 0.1667 - val_level_2_output_loss: 2.7861 - val_loss: 16.5909 - learning_rate: 1.0000e-04
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - level_1_output_accuracy: 0.4248 - level_1_output_loss: 1.6835 - level_2_output_accuracy: 0.1780 - level_2_output_loss: 3.2207 - loss: 16.4858 - val_level_1_output_accuracy: 0.3056 - val_level_1_output_loss: 2.2599 - val_level_2_output_accuracy: 0.1667 - val_level_2_output_loss: 2.8029 - val_loss: 16.5990 - learning_rate: 1.0000e-04
# Epoch 21/50
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step - level_1_output_accuracy: 0.4688 - level_1_output_loss: 1.4330 - level_2_output_accuracy: 0.3125 - level_2_output_loss: 2.5331 - loss: 15.4075
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - level_1_output_accuracy: 0.4299 - level_1_output_loss: 1.7001 - level_2_output_accuracy: 0.1949 - level_2_output_loss: 3.0886 - loss: 16.3069 - val_level_1_output_accuracy: 0.3333 - val_level_1_output_loss: 2.2819 - val_level_2_output_accuracy: 0.1111 - val_level_2_output_loss: 2.8058 - val_loss: 16.6551 - learning_rate: 1.0000e-04
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - level_1_output_accuracy: 0.4807 - level_1_output_loss: 1.6279 - level_2_output_accuracy: 0.1660 - level_2_output_loss: 3.0438 - loss: 16.1879 - val_level_1_output_accuracy: 0.3333 - val_level_1_output_loss: 2.2607 - val_level_2_output_accuracy: 0.1111 - val_level_2_output_loss: 2.8145 - val_loss: 16.6528 - learning_rate: 5.0000e-05
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - level_1_output_accuracy: 0.4440 - level_1_output_loss: 1.6019 - level_2_output_accuracy: 0.1828 - level_2_output_loss: 3.1051 - loss: 16.2195 - val_level_1_output_accuracy: 0.3333 - val_level_1_output_loss: 2.2811 - val_level_2_output_accuracy: 0.1111 - val_level_2_output_loss: 2.8166 - val_loss: 16.6694 - learning_rate: 5.0000e-05
# Epoch 24/50
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - level_1_output_accuracy: 0.5312 - level_1_output_loss: 1.4183 - level_2_output_accuracy: 0.1250 - level_2_output_loss: 2.8568 - loss: 15.7781
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - level_1_output_accuracy: 0.4687 - level_1_output_loss: 1.7383 - level_2_output_accuracy: 0.1489 - level_2_output_loss: 3.0472 - loss: 16.2452 - val_level_1_output_accuracy: 0.1944 - val_level_1_output_loss: 2.3397 - val_level_2_output_accuracy: 0.1389 - val_level_2_output_loss: 2.8009 - val_loss: 16.6923 - learning_rate: 5.0000e-05
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - level_1_output_accuracy: 0.4434 - level_1_output_loss: 1.7269 - level_2_output_accuracy: 0.1787 - level_2_output_loss: 3.1523 - loss: 16.3576 - val_level_1_output_accuracy: 0.1944 - val_level_1_output_loss: 2.3411 - val_level_2_output_accuracy: 0.1111 - val_level_2_output_loss: 2.8016 - val_loss: 16.6835 - learning_rate: 2.5000e-05
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - level_1_output_accuracy: 0.4315 - level_1_output_loss: 1.8850 - level_2_output_accuracy: 0.2002 - level_2_output_loss: 3.0352 - loss: 16.3170 - val_level_1_output_accuracy: 0.2500 - val_level_1_output_loss: 2.3471 - val_level_2_output_accuracy: 0.1111 - val_level_2_output_loss: 2.7939 - val_loss: 16.6809 - learning_rate: 2.5000e-05
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 18.

# %%
# Evaluation
evaluation = model.evaluate(
    X_test,
    {"level_1_output": y_test_level_1_onehot, "level_2_output": y_test_level_2_onehot},
    verbose=1,
)

print("Test Loss and Accuracy:", evaluation)

from sklearn.metrics import accuracy_score, f1_score
import numpy as np

# Get predictions from the model
predictions = model.predict(X_test)

# Extract predictions for level_1 and level_2
level_1_preds = np.argmax(predictions[0], axis=1)
level_2_preds = np.argmax(predictions[1], axis=1)

# Extract true labels for level_1 and level_2
level_1_true = np.argmax(y_test_level_1_onehot, axis=1)
level_2_true = np.argmax(y_test_level_2_onehot, axis=1)

# Compute Accuracy
level_1_accuracy = accuracy_score(level_1_true, level_1_preds)
level_2_accuracy = accuracy_score(level_2_true, level_2_preds)

# Compute F1-Score
level_1_f1 = f1_score(level_1_true, level_1_preds, average='weighted')
level_2_f1 = f1_score(level_2_true, level_2_preds, average='weighted')

# Print Evaluation Metrics
print(f"Level 1 Accuracy: {level_1_accuracy:.4f}")
print(f"Level 1 F1-Score: {level_1_f1:.4f}")
print(f"Level 2 Accuracy: {level_2_accuracy:.4f}")
print(f"Level 2 F1-Score: {level_2_f1:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step - level_1_output_accuracy: 0.3773 - level_1_output_loss: 1.7705 - level_2_output_accuracy: 0.1498 - level_2_output_loss: 3.1568 - loss: 16.6227
# Test Loss and Accuracy: [16.599348068237305, 1.8375935554504395, 3.0541582107543945, 0.37837839126586914, 0.1621621549129486]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 382ms/step
# Level 1 Accuracy: 0.3784
# Level 1 F1-Score: 0.3522
# Level 2 Accuracy: 0.1622
# Level 2 F1-Score: 0.1077

# %%
import random

# Extract true values
level_1_true = tf.argmax(y_test_level_1_onehot, axis=1).numpy()
level_2_true = tf.argmax(y_test_level_2_onehot, axis=1).numpy()

# Random 10 indices
random_indices = random.sample(range(len(X_test)), 10)


print("Random Sample of Predictions:")
for idx in random_indices:
    print(f"Index: {idx}")
    print(f"Level 1 True: {level_1_true[idx]} | Level 1 Pred: {level_1_preds[idx]}")
    print(f"Level 2 True: {level_2_true[idx]} | Level 2 Pred: {level_2_preds[idx]}")
    print("-" * 30)
# Out:
# Random Sample of Predictions:
# Index: 13
# Level 1 True: 3 | Level 1 Pred: 2
# Level 2 True: 17 | Level 2 Pred: 2
# ------------------------------
# Index: 9
# Level 1 True: 3 | Level 1 Pred: 3
# Level 2 True: 20 | Level 2 Pred: 6
# ------------------------------
# Index: 12
# Level 1 True: 3 | Level 1 Pred: 2
# Level 2 True: 20 | Level 2 Pred: 2
# ------------------------------
# Index: 0
# Level 1 True: 8 | Level 1 Pred: 3
# Level 2 True: 11 | Level 2 Pred: 6
# ------------------------------
# Index: 27
# Level 1 True: 8 | Level 1 Pred: 8
# Level 2 True: 8 | Level 2 Pred: 8
# ------------------------------
# Index: 33
# Level 1 True: 8 | Level 1 Pred: 2
# Level 2 True: 12 | Level 2 Pred: 2
# ------------------------------
# Index: 32
# Level 1 True: 2 | Level 1 Pred: 2
# Level 2 True: 3 | Level 2 Pred: 3
# ------------------------------
# Index: 35
# Level 1 True: 2 | Level 1 Pred: 2
# Level 2 True: 2 | Level 2 Pred: 2
# ------------------------------
# Index: 25
# Level 1 True: 8 | Level 1 Pred: 8
# Level 2 True: 6 | Level 2 Pred: 2
# ------------------------------
# Index: 6
# Level 1 True: 3 | Level 1 Pred: 3
# Level 2 True: 15 | Level 2 Pred: 17
# ------------------------------
